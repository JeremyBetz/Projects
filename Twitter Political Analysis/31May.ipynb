# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

from IPython import display
from textblob import TextBlob
import pickle


# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
with open("df_.pkl", 'rb') as picklefile: 
    df_ = pickle.load(picklefile)

# %%
handles2 = pd.read_csv("statsocial_political_journalists.csv")

del handles2['Unnamed: 7']
del handles2['Unnamed: 11']

handles2 = handles2['Username'].values.tolist()

with open("handles.pkl", 'rb') as picklefile: 
    handles = pickle.load(picklefile)

# %%
list1 = []
for index in range(len(handles2)):
    try:
        sheet = list(pd.read_csv('tweets/%s_tweets.csv' % handles2[index])['text'])
        list1.append(handles2[index])
    except:
        print("")

# %%
len(list1)
# Out:
# 188

# %%
with open('current_handles.pkl', 'wb') as picklefile:
    pickle.dump(list1, picklefile)

# %%
with open("current_handles.pkl", 'rb') as picklefile: 
    current_handles = pickle.load(picklefile)

# %%
current_handles
# Out:
# ['andersoncooper',
#  'maddow',
#  'jaketapper',
#  'gstephanopoulos',
#  'camanpour',
#  'ezraklein',
#  'NateSilver538',
#  'mikeallen',
#  'chucktodd',
#  'brianstelter',
#  'buzzfeedben',
#  'ariannahuff',
#  'chrislhayes',
#  'anncurry',
#  'megynkelly',
#  'seanhannity',
#  'wolfblitzer',
#  'thefix',
#  'fareedzakaria',
#  'ggreenwald',
#  'joenbc',
#  'daveweigel',
#  'markknoller',
#  'mitchellreports',
#  'michellemalkin',
#  'MHarrisPerry',
#  'howardkurtz',
#  'danaperino',
#  'bretbaier',
#  'greta',
#  'ahmalcolm',
#  'glennbeck',
#  'donnabrazile',
#  'davidcorndc',
#  'jdickerson',
#  'mattyglesias',
#  'katrinanation',
#  'edhenry',
#  'jmartnyt',
#  'samsteinhp',
#  'davidfrum',
#  'nycjim',
#  'krauthammer',
#  'majorcbs',
#  'dianesawyer',
#  'anncoulter',
#  'secupp',
#  'RBReich',
#  'lawrence',
#  'donlemon',
#  'rickklein',
#  'joshtpm',
#  'NickKristof',
#  'brithume',
#  'norahodonnell',
#  'dloesch',
#  'markos',
#  'blakehounshell',
#  'mtaibbi',
#  'markhalperin',
#  'maggieNYT',
#  'dleonhardt',
#  'sullydish',
#  'tavissmiley',
#  'tuckercarlson',
#  'thereval',
#  'tomfriedman',
#  'ewerickson',
#  'costareports',
#  'jeffreygoldberg',
#  'Peggynoonannyc',
#  'billkeller2014',
#  'jonkarl',
#  'ktumulty',
#  'greggutfeld',
#  'thegarance',
#  'stephenfhayes',
#  'chriscuomo',
#  'judgenap',
#  'RyanLizza',
#  'morningmika',
#  'williegeist',
#  'Jonahnro',
#  'LarrySabato',
#  'andreatantaros',
#  'dylanbyers',
#  'marcambinder',
#  'zekejmiller',
#  'KirstenPowers',
#  'kimguilfoyle',
#  'arimelber',
#  'aterkel',
#  'jbarro',
#  'teamcavuto',
#  'monicacrowley',
#  'mollyesque',
#  'capehartj',
#  'politicalwire',
#  'jheil',
#  'danbalz',
#  'nickconfessore',
#  'felixsalmon',
#  'anamariecox',
#  'toure',
#  'markleibovich',
#  'alexwagner',
#  'alexburnsNYT',
#  'charlesmblow',
#  'jamesfallows',
#  'attackerman',
#  'jonathanchait',
#  'richlowry',
#  'jillabramson',
#  'moody',
#  'johnjharwood',
#  'max_fisher',
#  'bobschieffer',
#  'aaronblakewp',
#  'mkhammer',
#  'cbellantoni',
#  'amyewalter',
#  'ron_fournier',
#  'lrozen',
#  'wesleylowery',
#  'alexwagner',
#  'digiphile',
#  'jodikantor',
#  'tamronhall',
#  'edshow',
#  'ehasselbeck',
#  'ericbolling',
#  'andylevy',
#  'billhemmer',
#  'peterbakernyt',
#  'davidmuir',
#  'mattklewis',
#  'politicoroger',
#  'AnneBayefsky',
#  'kate_sheppard',
#  'ErinBurnett',
#  'hotlinejosh',
#  'martharaddatz',
#  'brianbeutler',
#  'tanehisicoates',
#  'michaelscherer',
#  'philiprucker',
#  'edatpost',
#  'EliLake',
#  'fredbarnes',
#  'marthamaccallum',
#  'jonathanweisman',
#  'susanpage',
#  'nicopitney',
#  'jimpethokoukis',
#  'rosiegray',
#  'jimgeraghty',
#  'davidmwessel',
#  'mckaycoppins',
#  'elisefoley',
#  'milbank',
#  'chadpergram',
#  'mmurraypolitics',
#  'stevekornacki',
#  'heytammybruce',
#  'iowahawkblog',
#  'melissatweets',
#  'DineshDSouza',
#  'oknox',
#  'krystalball',
#  'jakesherman',
#  'jpodhoretz',
#  'feliciasonmez',
#  'lesterholtnbc',
#  'lynnsweet',
#  'kilmeade',
#  'nickbilton',
#  'politichickAM',
#  'JRubinBlogger',
#  'jonward11',
#  'kdrum',
#  'philip_elliott',
#  'joshuagreen',
#  'froomkin',
#  'glennthrush',
#  'michaelcrowley',
#  'foxnewssunday',
#  'geraldfseib',
#  'davidmuir']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fc7406f2104> in <module>()
#       1 thefile = open('corpus.txt', 'w')
#       2
# ----> 3 for tweet in corpus:
#       4   print>>thefile, tweet
#
# NameError: name 'corpus' is not defined
